# %% [markdown]
# <a href="https://colab.research.google.com/github/ved079/EDS-ass/blob/main/Practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("imdb data.csv")
print(df)
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %%
print(df[['Series_Title','Released_Year']])
# Out:
#                  Series_Title Released_Year
# 0    The Shawshank Redemption          1994
# 1               The Godfather          1972
# 2             The Dark Knight          2008
# 3      The Godfather: Part II          1974
# 4                12 Angry Men          1957
# ..                        ...           ...
# 995    Breakfast at Tiffany's          1961
# 996                     Giant          1956
# 997     From Here to Eternity          1953
# 998                  Lifeboat          1944
# 999              The 39 Steps          1935
#
# [1000 rows x 2 columns]

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.mean()
# Out:
# <ipython-input-7-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# IMDB_Rating         7.94930
# Meta_score         77.97153
# No_of_Votes    273692.91100
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-8-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# IMDB_Rating         7.9
# Meta_score         79.0
# No_of_Votes    138548.5
# dtype: float64

# %%
df.loc[df["Meta_score"].max()]
# Out:
# Series_Title          Bacheha-Ye aseman
# Released_Year                      1997
# Certificate                          PG
# Runtime                          89 min
# Genre              Drama, Family, Sport
# IMDB_Rating                         8.3
# Meta_score                         77.0
# Director                   Majid Majidi
# Star1                Mohammad Amir Naji
# Star2            Amir Farrokh Hashemian
# No_of_Votes                       65341
# Gross                           933,933
# Name: 100, dtype: object

# %%
df["No_of_Votes"].describe()
# Out:
# count    1.000000e+03
# mean     2.736929e+05
# std      3.273727e+05
# min      2.508800e+04
# 25%      5.552625e+04
# 50%      1.385485e+05
# 75%      3.741612e+05
# max      2.343110e+06
# Name: No_of_Votes, dtype: float64

# %%
df.count()
# Out:
# Series_Title     1000
# Released_Year    1000
# Certificate       899
# Runtime          1000
# Genre            1000
# IMDB_Rating      1000
# Meta_score        843
# Director         1000
# Star1            1000
# Star2            1000
# No_of_Votes      1000
# Gross             831
# dtype: int64

# %%
print(df.loc[df['IMDB_Rating']>9])
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando
#
#             Star2  No_of_Votes        Gross
# 0  Morgan Freeman      2343110   28,341,469
# 1       Al Pacino      1620367  134,966,411

# %%
df.loc[ (df['IMDB_Rating']>8) & (df['No_of_Votes'] <689845) ]
# Out:
#                         Series_Title Released_Year Certificate  Runtime  \
# 12   Il buono, il brutto, il cattivo          1966           A  161 min
# 18                          Hamilton          2020       PG-13  160 min
# 19                      Gisaengchung          2019           A  132 min
# 20                   Soorarai Pottru          2020           U  153 min
# 23     Sen to Chihiro no kamikakushi          2001           U  125 min
# ..                               ...           ...         ...      ...
# 317       La passion de Jeanne d'Arc          1928      Passed  110 min
# 318                       The Circus          1928      Passed   72 min
# 319    Sunrise: A Song of Two Humans          1927      Passed   94 min
# 320                      The General          1926      Passed   67 min
# 321     Das Cabinet des Dr. Caligari          1920         NaN   76 min
#
#                             Genre  IMDB_Rating  Meta_score  \
# ...

# %%
print(df.iloc[::-1])
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 999              The 39 Steps          1935         NaN   86 min
# 998                  Lifeboat          1944         NaN   97 min
# 997     From Here to Eternity          1953      Passed  118 min
# 996                     Giant          1956           G  201 min
# 995    Breakfast at Tiffany's          1961           A  115 min
# ..                        ...           ...         ...      ...
# 4                12 Angry Men          1957           U   96 min
# 3      The Godfather: Part II          1974           A  202 min
# 2             The Dark Knight          2008          UA  152 min
# 1               The Godfather          1972           A  175 min
# 0    The Shawshank Redemption          1994           A  142 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 999  Crime, Mystery, Thriller          7.6        93.0      Alfred Hitchcock
# ...

# %%
print(df.groupby('Runtime').count())
# Out:
#          Series_Title  Released_Year  Certificate  Genre  IMDB_Rating  \
# Runtime
# 100 min            23             23           21     23           23
# 101 min            22             22           20     22           22
# 102 min            18             18           18     18           18
# 103 min            14             14           13     14           14
# 104 min            15             15           14     15           15
# ...               ...            ...          ...    ...          ...
# 95 min             13             13           10     13           13
# 96 min             17             17           13     17           17
# 97 min              9              9            7      9            9
# 98 min             11             11           10     11           11
# 99 min             14             14           12     14           14
#
#          Meta_score  Director  Star1  Star2  No_of_Votes  Gross
# Runtime
# ...

# %%
df.groupby('Certificate').get_group('A')
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 3      The Godfather: Part II          1974           A  202 min
# 6                Pulp Fiction          1994           A  154 min
# 7            Schindler's List          1993           A  195 min
# ..                        ...           ...         ...      ...
# 985      Escape from Alcatraz          1979           A  112 min
# 987          Midnight Express          1978           A  121 min
# 989          The Long Goodbye          1973           A  112 min
# 993                    Blowup          1966           A  111 min
# 995    Breakfast at Tiffany's          1961           A  115 min
#
#                          Genre  IMDB_Rating  Meta_score  \
# 0                        Drama          9.3        80.0
# 1                 Crime, Drama          9.2       100.0
# ...

# %%
df.head(20)
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# 4                                        12 Angry Men          1957
# 5       The Lord of the Rings: The Return of the King          2003
# 6                                        Pulp Fiction          1994
# 7                                    Schindler's List          1993
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                       Forrest Gump          1994
# 12                    Il buono, il brutto, il cattivo          1966
# ...

# %%
df.tail(20)
# Out:
#                            Series_Title Released_Year Certificate  Runtime  \
# 980                        Blood Simple          1984           A   99 min
# 981                      On Golden Pond          1981          UA  109 min
# 982                           Mad Max 2          1981           A   96 min
# 983                        The Warriors          1979          UA   92 min
# 984                    The Muppet Movie          1979           U   95 min
# 985                Escape from Alcatraz          1979           A  112 min
# 986                      Watership Down          1978           U   91 min
# 987                    Midnight Express          1978           A  121 min
# 988  Close Encounters of the Third Kind          1977           U  138 min
# 989                    The Long Goodbye          1973           A  112 min
# 990                        Giù la testa          1971          PG  157 min
# ...

# %%
print(df.groupby('Director').count())
# Out:
#                      Series_Title  Released_Year  Certificate  Runtime  Genre  \
# Director
# Aamir Khan                      1              1            1        1      1
# Aaron Sorkin                    1              1            1        1      1
# Abdellatif Kechiche             1              1            1        1      1
# Abhishek Chaubey                1              1            1        1      1
# Abhishek Kapoor                 1              1            1        1      1
# ...                           ...            ...          ...      ...    ...
# Zack Snyder                     2              2            2        2      2
# Zaza Urushadze                  1              1            0        1      1
# Zoya Akhtar                     2              2            2        2      2
# Çagan Irmak                     1              1            0        1      1
# Ömer Faruk Sorak                1              1            0        1      1
#
# ...

# %%
df['Meta_score'].value_counts()
# Out:
# 76.0    32
# 84.0    29
# 90.0    29
# 80.0    27
# 73.0    27
#         ..
# 28.0     1
# 36.0     1
# 46.0     1
# 30.0     1
# 41.0     1
# Name: Meta_score, Length: 63, dtype: int64

# %%
[df['IMDB_Rating'].max()]
# Out:
# [9.3]

# %%
df['Series_Title']
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %%
df['Star1']
# Out:
# 0            Tim Robbins
# 1          Marlon Brando
# 2         Christian Bale
# 3              Al Pacino
# 4            Henry Fonda
#              ...
# 995       Audrey Hepburn
# 996     Elizabeth Taylor
# 997       Burt Lancaster
# 998    Tallulah Bankhead
# 999         Robert Donat
# Name: Star1, Length: 1000, dtype: object

# %%
df['Star2']
# Out:
# 0         Morgan Freeman
# 1              Al Pacino
# 2           Heath Ledger
# 3         Robert De Niro
# 4            Lee J. Cobb
#              ...
# 995       George Peppard
# 996          Rock Hudson
# 997     Montgomery Clift
# 998          John Hodiak
# 999    Madeleine Carroll
# Name: Star2, Length: 1000, dtype: object
